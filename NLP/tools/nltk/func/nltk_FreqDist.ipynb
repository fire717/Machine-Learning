# %%
import nltk
######## NLTK 频率分布类中定义的函数 ###
fdist = nltk.FreqDist(['ok','no','good','ok'])
print(fdist['ok'])  #给定词的次数
print(fdist.max())  #频次最大的样本
fdist.tabulate()    #频率分布表
fdist.plot()        #分布图
fdist.plot(cumulative=True)  #累计频率图
# Out:
# 2
# ok
#   ok good   no
#    2    1    1
